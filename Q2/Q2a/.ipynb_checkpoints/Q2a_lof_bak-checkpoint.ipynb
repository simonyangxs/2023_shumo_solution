# %% [markdown]
# # 水肿体积随时间变化曲线 拟合+计算残差
# > a)  请根据“表2”前100个患者（sub001至sub100）的水肿体积（ED_volume）和重复检查时间点，构建一条全体患者水肿体积随时间进展曲线
# （x轴：发病至影像检查时间，y轴：水肿体积，y=f(x)），
# 计算前100个患者（sub001至sub100）真实值和所拟合曲线之间存在的残差。
# 结果填写规范：记录残差，填写位置“表4”F字段（残差（全体））。

# %% [markdown]
# ## 读入数据
# 理论上此处需要使用三个文件：
# - 表1-患者列表及临床信息（用于确定发病时间）
# - 表2-患者影像信息血肿及水肿的体积及位置（用于获取每次检查时的肿块体积和检查流水号）
# - 附表1-检索表格-流水号vs时间（基于检查流水号获取检查时间点）
#
# 用 Q1a 的中间结果替代时间间隔数据更快一些

# %%
import pandas as pd
import math

# %%
tab_1 = pd.read_excel('~/shumo/metadata/表1-患者列表及临床信息.xlsx')
tab_1 = tab_1.rename(columns={'Unnamed: 0': 'ID'})

# tab_2 = pd.read_excel('~/shumo/metadata/表2-患者影像信息血肿及水肿的体积及位置.xlsx')

ann_tab = pd.read_excel('~/shumo/metadata/附表1-检索表格-流水号vs时间(1).xlsx')

# %%
# 沿用 Q1a 的处理代码获取 ED_volume
tab2_dict = {}
for i, sheet_name in enumerate(['首次', '随访1', '随访2', '随访3', '随访4', '随访5', '随访6', '随访7', '随访8']):
    if sheet_name == '首次':
        col = '首次检查流水号'
    else:
        col = sheet_name + '流水号'

    tab2_dict[i] = pd.read_excel('~/shumo/metadata/表2-患者影像信息血肿及水肿的体积及位置.xlsx', sheet_name=sheet_name, usecols=['ID', col, 'HM_volume', 'ED_volume'])

# %%
# 从 Q1a 获取一个中间结果：包含发病时间和每次检查的时间间隔
tab2_cmp = pd.read_excel("~/shumo/Q1/Q1a/processed/Q1a_record.xlsx", usecols=['ID', 'interval_1', 'interval_2','interval_3','interval_4','interval_5','interval_6','interval_7','interval_8'])

# %%
tab2_cmp
# Out:
#          ID  interval_1  interval_2  interval_3   interval_4  interval_5  \
# 0    sub001    8.268333  132.108333  259.737500   425.538333         NaN
# 1    sub002   14.923333   69.221944  448.016389  1119.191944         NaN
# 2    sub003    9.522500   39.595833         NaN          NaN         NaN
# 3    sub004   16.974167   83.845278  227.501111          NaN         NaN
# 4    sub005   26.467500   97.943056         NaN          NaN         NaN
# ..      ...         ...         ...         ...          ...         ...
# 155  sub156   24.881944  125.615833  293.317222          NaN         NaN
# 156  sub157    1.366667    7.116667   20.066667          NaN         NaN
# 157  sub158   18.383333   71.300000  308.650000          NaN         NaN
# 158  sub159   26.533333         NaN         NaN          NaN         NaN
# 159  sub160   17.483333         NaN         NaN          NaN         NaN
#
#      interval_6  interval_7  interval_8
# 0           NaN         NaN         NaN
# 1           NaN         NaN         NaN
# 2           NaN         NaN         NaN
# 3           NaN         NaN         NaN
# 4           NaN         NaN         NaN
# ..          ...         ...         ...
# 155         NaN         NaN         NaN
# 156         NaN         NaN         NaN
# 157         NaN         NaN         NaN
# 158         NaN         NaN         NaN
# 159         NaN         NaN         NaN
#
# [160 rows x 9 columns]

# %% [markdown]
# ## 获取每个时间点下的水肿体积

# %%
# 获得每个病人每次测量的水肿体积和对应时间间隔（指从发病到该次检测的时间间隔）
# 指计算前 100 个患者

patient_ED_dict = dict()
# 同时获取一下血肿体积
patient_HM_dict = dict()

for patient in tab_1["ID"].tolist()[:100]:
    
    patient_ED_dict[patient] = []
    patient_HM_dict[patient] = []
    
    # 获取时间间隔
    first_interval = tab_1.loc[tab_1["ID"] == patient]["发病到首次影像检查时间间隔"].values[0]
    interval_time = [first_interval] + tab2_cmp.loc[tab2_cmp['ID'] == patient].values.tolist()[0][1:]
    
    # 获取每次的水肿数量
    for check in range(9): # 最多只有1次检查+8次随访记录
        
        ed_v = tab2_dict[check].loc[tab2_dict[check]["ID"] == patient].values[0][3]
        hm_v = tab2_dict[check].loc[tab2_dict[check]["ID"] == patient].values[0][2]
        
        # 如果此次随访已没有记录则跳出
        if pd.isna(ed_v):
            break
        
        ed_v = ed_v
        hm_v = hm_v
        patient_ED_dict[patient].append((interval_time[check], ed_v))
        patient_HM_dict[patient].append((interval_time[check], hm_v))

# %%
# 保存数据
pd.to_pickle(patient_ED_dict, "patient_ED_dict.pkl")

# %% [markdown]
# ## 时序数据可视分析

# %%
patient_ED_dict = pd.read_pickle(patient_ED_dict, "patient_ED_dict.pkl")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
time = []
vol = []
hm_vol = []
for person in patient_ED_dict:
    seq = patient_ED_dict[person]
    seq_hm = patient_HM_dict[person]
    # 时间间隔
    time += [i[0] for i in seq]
    # 体积
    vol += [i[1] / 1000 for i in seq] # 单位统一到 ml
    # 血肿体积
    hm_vol += [i[1] / 1000 for i in seq_hm]

# %%
# %matplotlib inline

# %%
# 单变量分析：水肿的分布
plt.close()

plt.figure(figsize=(8, 6))
sns.boxplot(x=vol)
plt.xlabel('水肿体积（ml）')
# plt.ylabel('分布频率')

plt.show()

# %%
# 单变量分析：水肿的分布
plt.close()

plt.figure(figsize=(8, 6))
sns.boxplot(x=time)
plt.xlabel('时间间隔（h）')
# plt.ylabel('分布频率')

plt.show()

# %%
# 计算条形图相关参数
mean = np.mean(vol)  # 平均值
median = np.median(vol)  # 中位数
std = np.std(vol)  # 标准差
min_value = np.min(vol)  # 最小值
max_value = np.max(vol)  # 最大值

# 输出条形图相关参数
print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std)
print("Min Value:", min_value)
print("Max Value:", max_value)
# Out:
# Mean: 26.561
# Median: 18.988999999999997
# Standard Deviation: 26.065960710900764
# Min Value: 0.0
# Max Value: 168.138

# %%
# 分样本散点图
pat = [i+1 for i in range(100)]

y_seq = [] # y轴数据是患者序号
time_seq = [] # 仍然作为 y轴
val_seq = [] # 作为散点的数值存在

for person in patient_ED_dict:
    seq = patient_ED_dict[person]
    # 时间间隔
    time_seq += [i[0] for i in seq]
    # 体积
    val_seq += [i[1] / 1000 for i in seq] # 单位统一到 ml
    # 患者序号
    y_seq += [int(person[3:]) for i in range(len(seq))]

# %%
# 双变量分析：分样本散点图
# 横坐标 检测到发病的时间点
# 纵坐标 患者序号
# 散点颜色 水肿体积（ml）
plt.close()

rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)

plt.figure(figsize=(8, 6))

sns.color_palette("light:b", as_cmap=True)

sns.scatterplot(x=time_seq, y=y_seq, hue=val_seq, palette='light:b')

plt.xscale('log')
plt.grid(True)
plt.xlabel("发病到影像检查时间间隔（h）")
plt.ylabel("患者序号")

plt.show()

# %% [markdown]
# 从图中可以大致看出发病后 100h 后水肿体积开始明显增大
# 下图将所有患者的数据混合

# %%
# 双变量分析：综合散点图
# 横坐标 检测到发病的时间点
# 纵坐标 检测时对应的水肿体积（ml）
plt.close()

rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=time, y=vol)
plt.grid(True)
plt.xlabel("发病到影像检查时间间隔（h）")
plt.ylabel("水肿总体积（ml）")
# plt.xscale('log')

plt.show()

# %%
# 横轴取 log 之后，与分样本观察的规律一致
plt.close()

rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=time, y=vol)

plt.grid(True)
plt.xlabel("发病到影像检查时间间隔-取对数（h）")
plt.ylabel("水肿总体积（ml）")
plt.xscale('log')

plt.show()

# %% [markdown]
# 说明水肿与发病时间间隔间应该存在潜在关联，并且是较为普适的。
# 下面进行回归分析

# %% [markdown]
# ## 数据预处理-去除离群点

# %%
# 数据转为 ndarray
time_np = np.array(time).reshape(-1, 1)
vol_np = np.array(vol).ravel()
hm_vol_np = np.array(hm_vol).ravel()

# 剩下的正常数据
# time_res = [i[0] for i in reserve_data]
# vol_res = [i[1] for i in reserve_data]

# time_np_res = np.array(time_res).reshape(-1, 1)
# vol_np_res = np.array(vol_res).ravel()

# %%
# 对原始数据进行排序
new_index = np.argsort(time_np, axis=0)
time_sorted = time_np[new_index].reshape(-1, 1)
vol_sorted = vol_np[new_index].reshape(-1, 1)
hm_vol_sorted = hm_vol_np[new_index].reshape(-1, 1)

# %% [markdown]
# ### 基于时间：根据其他论文的结论截取前60天
# 即1440小时以内的数据
# 排序之后 第438是1397h，第439是1668h（超出了）。**保留到** 438 即可

# %%
# 保留指定时间下的数据
time_sorted_res = time_sorted[:439]
vol_sorted_res = vol_sorted[:439]
hm_sorted_res = hm_vol_sorted[:439]

# %%
# 将日期截断之后的数据进行可视化
plt.close()

plt.figure(figsize=(8, 6))
sns.scatterplot(x=time_sorted_res.flatten(), y=vol_sorted_res.flatten())

plt.grid(True)
plt.xlabel("发病到影像检查时间间隔-取对数（h）")
plt.ylabel("水肿总体积（ml）")
plt.xscale('log')

plt.show()

# %% [markdown]
# ### 基于密度的方法-LOF

# %% [markdown]
# （可以可视化样本点）

# %%
from sklearn.neighbors import LocalOutlierFactor

# %%
zip_feat = list(zip(time_sorted_res.flatten(), vol_sorted_res.flatten()))

# %%
# 创建LOF模型
# 剔除10%的异常样本点
lof = LocalOutlierFactor(n_neighbors=10, contamination=0.05)

y_pred_lof = lof.fit_predict(zip_feat)

# 获取样本的异常值得分
scores = lof.negative_outlier_factor_

# 打印样本的异常值得分和预测结果
formal_data = []
for i, (score, pred) in enumerate(zip(scores, y_pred_lof)):
    if pred == 1:
        formal_data.append([zip_feat[i][0], zip_feat[i][1], hm_sorted_res[i].item()])

# %%
time_sorted_formal = [i[0] for i in formal_data]
vol_sorted_formal = [i[1] for i in formal_data]
hm_sorted_formal = [i[2] for i in formal_data]

time_formal_np = np.array(time_sorted_formal).reshape(-1, 1)
vol_formal_np = np.array(vol_sorted_formal).reshape(-1, 1)
hm_formal_np = np.array(hm_sorted_formal).reshape(-1, 1)

# %%
# 对正常数据进行排序（前面排过，这里不用排了）
# new_index = np.argsort(time_np_res, axis=0)
# time_sorted_res = time_np_res[new_index].reshape(-1, 1)
# vol_sorted_res = vol_np_res[new_index].reshape(-1, 1)
print("异常点数量")
print(time_formal_np.shape)
# Out:
# 异常点数量
# (417, 1)

# %%
# 可视化异常点
plt.close()

plt.figure(figsize=(8, 6))

sns.scatterplot(x=time_sorted_res.flatten(), y=vol_sorted_res.flatten(), alpha=0.3, color="gray")
sns.scatterplot(x=time_formal_np.flatten(), y=vol_formal_np.flatten())

plt.grid(True)
plt.xlabel("发病到影像检查时间间隔-取对数（h）")
plt.ylabel("水肿总体积（ml）")
plt.xscale('log')

plt.show()

# %% [markdown]
# ## 时序数据回归分析
# 样本点数量：450
# 截断+排除异常点后的数据

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

# %% [markdown]
# ### 传统回归分析
# 1. 线性回归模型
# 2. 多项式回归模型
# 3. 非线性回归模型
#     - 指数函数
#     - 对数函数
#     - 幂函数
# 4. 广义线性模型
#     - 线性回归
#     - 逻辑回归
#     - 泊松回归

# %% [markdown]
# #### 线性回归

# %%
# 线性回归
linear_model = LinearRegression()
linear_model.fit(time_formal_np, vol_formal_np)

y_pred = linear_model.predict(time_formal_np)

# 计算均方误差
# residuals = vol_sorted - y_pred
mse = mean_squared_error(vol_formal_np, y_pred)
r2 = r2_score(vol_formal_np, y_pred)
# print("残差：", residuals)
print("均方误差：", mse)
print("R2:", r2)
# Out:
# 均方误差： 548.613334992961
# R2: 0.006995856408935075

# %%
# 绘制回归线
plt.close()

plt.figure(figsize=(8, 6))
sns.scatterplot(x=time_formal_np.flatten(), y=vol_formal_np.flatten(), label='Actual')
plt.plot(time_formal_np.flatten(), y_pred, color='red', label='Regression Line (Linear Regression)', alpha=0.8)
plt.xlabel('发病到影像检查时间间隔-取对数（h）')
plt.xscale('log')
plt.ylabel('水肿总体积（ml）')
plt.legend()

plt.show()

# %% [markdown]
# #### 多元线性回归

# %%
# 多元线性回归

mse_l = []
r2_l = []

def poly_linear_r(degree):
    poly_feat = PolynomialFeatures(degree=degree)
    train_feat = poly_feat.fit_transform(time_formal_np)

    # 创建线性回归模型
    linear_model = LinearRegression()

    # 训练模型
    linear_model.fit(train_feat, vol_formal_np)

    y_pred = linear_model.predict(train_feat)

    # 计算指标
    mse = mean_squared_error(vol_formal_np, y_pred)
    r2 = r2_score(vol_formal_np, y_pred)
    
    return (mse, r2, y_pred)
    
for d in range(1, 10):
    mse, r2, _ = poly_linear_r(d)
    mse_l.append(mse)
    r2_l.append(r2)

# %%
# degree参数挑选
plt.close()

plt.figure(figsize=(8, 6))

degree_range = [d for d in range(1, 10)]

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

# mse 线
sns.lineplot(x=degree_range, y=mse_l, ax=ax1)
ax1.set_ylabel('MSE')
# r2 线
sns.lineplot(x=degree_range, y=r2_l, ax=ax2, color='red')
ax2.set_ylabel('R^2')

plt.xlabel('X')
# plt.ylabel('y')

plt.show()

# %%
mse, r2, y_pred = poly_linear_r(5)

# %%
print("mse:", mse, "\tr2:", r2)
# Out:
# mse: 497.67678722880567 	r2: 0.09919230837939153

# %%
# 绘制多元回归线
plt.close()

plt.figure(figsize=(8, 6))
sns.scatterplot(x=time_formal_np.flatten(), y=vol_formal_np.flatten(), label='Actual')
# sns.scatterplot(x=time_sorted_res.flatten(), y=y_pred.flatten(), color='red', label='Regression Line (Poly, degree=5)', alpha=0.8)
plt.plot(time_formal_np.flatten(), y_pred, color='red', label='Regression Line (Poly, degree=5)', alpha=0.8)
plt.xlabel('发病到影像检查时间间隔-取对数（h）')
plt.ylabel('水肿总体积（ml）')
plt.xscale('log')
plt.xlim(0, 1400)
plt.legend()

plt.show()
# Out:
# /tmp/ipykernel_48585/1235440141.py:11: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 1400)

# %% [markdown]
# #### 指数回归

# %%
# 指数回归
time_sorted_transformed = np.log(time_formal_np)

exp_model = LinearRegression()
exp_model.fit(time_sorted_transformed, vol_formal_np)

y_pred = linear_model.predict(time_sorted_transformed)

# 计算均方误差
# residuals = vol_sorted - y_pred
mse = mean_squared_error(vol_formal_np, y_pred)
r2 = r2_score(vol_formal_np, y_pred)
# print("残差：", residuals)
print("均方误差：", mse)
print("R2:", r2)
# Out:
# 均方误差： 554.2760832018331
# R2: -0.003253862431010779

# %%
# 绘制回归线
plt.close()

plt.figure(figsize=(8, 6))
sns.scatterplot(x=time_formal_np.flatten(), y=vol_formal_np.flatten(), label='Actual')
plt.plot(time_formal_np.flatten(), y_pred, color='red', label='Regression Line (exp)', alpha=0.8)
plt.xlabel('发病到影像检查时间间隔-取对数（h）')
plt.xscale('log')
plt.ylabel('水肿总体积（ml）')
plt.legend()

plt.show()

# %% [markdown]
# #### 对数回归

# %%
# 指数回归
vol_sorted_transformed = np.log(vol_formal_np + 1e-10)

log_model = LinearRegression()
log_model.fit(time_formal_np, vol_sorted_transformed)

y_pred_log = linear_model.predict(time_formal_np)
# 转换预测结果
y_pred = np.exp(y_pred_log)

# 计算均方误差
# residuals = vol_sorted - y_pred
mse = mean_squared_error(vol_formal_np, y_pred)
r2 = r2_score(vol_formal_np, y_pred)
# print("残差：", residuals)
print("均方误差：", mse)
print("R2:", r2)
# Out:
# 均方误差： 1.94450589469693e+27
# R2: -3.5196053167320054e+24

# %% [markdown]
# 指数和对数 应该不太行，因为这两个变量之间指数或对数关系不是特别明显

# %% [markdown]
# #### 最小二乘回归

# %%
from scipy.optimize import curve_fit

# %%
# 定义幂函数模型
def power_func(x, a, b):
    return a * np.power(x, b)

# 使用最小二乘法进行幂函数回归
params, params_covariance = curve_fit(power_func, time_formal_np.flatten(), vol_formal_np.flatten())

# 提取回归参数
a = params[0]
b = params[1]

# %%
y_pred = power_func(time_formal_np.flatten(), a, b)

mse = mean_squared_error(vol_formal_np, y_pred)
r2 = r2_score(vol_formal_np, y_pred)

print("均方误差：", mse)
print("R2:", r2)
# Out:
# 均方误差： 520.7625068785677
# R2: 0.05740656638628161

# %%
# 绘制回归线
plt.close()

plt.figure(figsize=(8, 6))
sns.scatterplot(x=time_formal_np.flatten(), y=vol_formal_np.flatten(), label='Actual')
plt.plot(time_formal_np.flatten(), y_pred, color='red', label='Regression Line (LS)', alpha=0.8)
plt.xlabel('发病到影像检查时间间隔-取对数（h）')
plt.xscale('log')
plt.ylabel('水肿总体积（ml）')
plt.legend()

plt.show()

# %% [markdown]
# #### ARIMA模型

# %%
from statsmodels.tsa.arima.model import ARIMA
# from statsmodels.tsa.arima_model import ARIMA

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.api import ExponentialSmoothing
# from statsmodels.tsa.arima.model import auto_arima
# from arch import arch_model
# 查看数据集
# import statsmodels.api as sm

# %%
from statsmodels.tsa.stattools import adfuller

# %%
data_df = pd.DataFrame({"time":time_formal_np.flatten(), "vol":vol_formal_np.flatten()})

# %%
def try_arima(p, d, q):
    # 创建ARIMA模型对象
    arima_model = ARIMA(data_df.vol, order=(p, d, q))

    # 拟合模型
    model_fit = arima_model.fit()

    # 进行预测
    predict = model_fit.predict(start=0, end=416)
    
    mse = mean_squared_error(data_df.vol, predict)
    r2 = r2_score(data_df.vol, predict)
    
    return predict, mse, r2
    # return mse # 这个在grid search的时候用

# %%
import tqdm

# %%
# Grid Search
mse_dict = dict()

for p in tqdm.tqdm(range(0, 10)):
    for d in range(0, 2):
        for q in range(0, 10):
            mse_dict[(p, d, q)] = try_arima(p, d, q)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  10%|█         | 1/10 [00:04<00:39,  4.38s/it]/home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  20%|██        | 2/10 [00:15<01:04,  8.07s/it]/home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  30%|███       | 3/10 [00:29<01:17, 11.04s/it]/home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  40%|████      | 4/10 [00:49<01:27, 14.58s/it]/home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  50%|█████     | 5/10 [01:10<01:24, 16.81s/it]/home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  60%|██████    | 6/10 [01:34<01:17, 19.32s/it]/home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  70%|███████   | 7/10 [01:59<01:03, 21.21s/it]/home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  80%|████████  | 8/10 [02:26<00:45, 22.91s/it]/home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  90%|█████████ | 9/10 [02:57<00:25, 25.58s/it]/home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  90%|█████████ | 9/10 [03:24<00:22, 22.68s/it]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /tmp/ipykernel_48585/389312649.py in <module>
#       5     for d in range(0, 2):
#       6         for q in range(0, 10):
# ----> 7             mse_dict[(p, d, q)] = try_arima(p, d, q)
#
# /tmp/ipykernel_48585/211642733.py in try_arima(p, d, q)
#       4
#       5     # 拟合模型
# ----> 6     model_fit = arima_model.fit()
#       7
#       8     # 进行预测
#
# ~/.local/lib/python3.9/site-packages/statsmodels/tsa/arima/model.py in fit(self, start_params, transformed, includes_fixed, method, method_kwargs, gls, gls_kwargs, cov_type, cov_kwds, return_params, low_memory)
#     393                 method_kwargs.setdefault('disp', 0)
#     394
# --> 395                 res = super().fit(
#     396                     return_params=return_params, low_memory=low_memory,
#     397                     cov_type=cov_type, cov_kwds=cov_kwds, **method_kwargs)
#
# ~/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     702                 flags['hessian_method'] = optim_hessian
#     703             fargs = (flags,)
# --> 704             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     705                                                fargs=fargs,
#     706                                                maxiter=maxiter,
#
# ~/.local/lib/python3.9/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     564
#     565         optimizer = Optimizer()
# --> 566         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                        fargs, kwargs,
#     568                                                        hessian=hess,
#
# ~/.local/lib/python3.9/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     240
#     241         func = fit_funcs[method]
# --> 242         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     243                              disp=disp, maxiter=maxiter, callback=callback,
#     244                              retall=retall, full_output=full_output,
#
# ~/.local/lib/python3.9/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     657         func = f
#     658
# --> 659     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     660                                      callback=callback, args=fargs,
#     661                                      bounds=bounds, disp=disp,
#
# ~/.conda/envs/cvtask/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# ~/.conda/envs/cvtask/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/.conda/envs/cvtask/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     266             self._update_x_impl(x)
#     267         self._update_fun()
# --> 268         self._update_grad()
#     269         return self.f, self.g
#     270
#
# ~/.conda/envs/cvtask/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     236     def _update_grad(self):
#     237         if not self.g_updated:
# --> 238             self._update_grad_impl()
#     239             self.g_updated = True
#     240
#
# ~/.conda/envs/cvtask/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     153                 self._update_fun()
#     154                 self.ngev += 1
# --> 155                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     156                                            **finite_diff_options)
#     157
#
# ~/.conda/envs/cvtask/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     484
#     485         if sparsity is None:
# --> 486             return _dense_difference(fun_wrapped, x0, f0, h,
#     487                                      use_one_sided, method)
#     488         else:
#
# ~/.conda/envs/cvtask/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# ~/.conda/envs/cvtask/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# ~/.conda/envs/cvtask/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# ~/.local/lib/python3.9/site-packages/statsmodels/base/model.py in f(params, *args)
#     532
#     533         def f(params, *args):
# --> 534             return -self.loglike(params, *args) / nobs
#     535
#     536         if method == 'newton':
#
# ~/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/mlemodel.py in loglike(self, params, *args, **kwargs)
#     937             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     938
# --> 939         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     940
#     941         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/kalman_filter.py in loglike(self, **kwargs)
#     999         kwargs.setdefault('conserve_memory',
#    1000                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# -> 1001         kfilter = self._filter(**kwargs)
#    1002         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#    1003                                         self.loglikelihood_burn)
#
# ~/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     919
#     920         # Initialize the state
# --> 921         self._initialize_state(prefix=prefix, complex_step=complex_step)
#     922
#     923         # Run the filter
#
# ~/.local/lib/python3.9/site-packages/statsmodels/tsa/statespace/representation.py in _initialize_state(self, prefix, complex_step)
#    1056             if not self.initialization.initialized:
#    1057                 raise RuntimeError('Initialization is incomplete.')
# -> 1058             self._statespaces[prefix].initialize(self.initialization,
#    1059                                                  complex_step=complex_step)
#    1060         else:
#
# statsmodels/tsa/statespace/_representation.pyx in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# statsmodels/tsa/statespace/_representation.pyx in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# statsmodels/tsa/statespace/_initialization.pyx in statsmodels.tsa.statespace._initialization.dInitialization.initialize()
#
# statsmodels/tsa/statespace/_initialization.pyx in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov()
#
# statsmodels/tsa/statespace/_tools.pyx in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov()
#
# LinAlgError: LU decomposition error.

# %%
# 获取最优参数组
min_item = min(mse_dict, key=mse_dict.get)
# 输出最优参数及对应的 mse
print(min_item, mse_dict[min_item])
# (7, 0, 8), mse=457.3727933686476
# r2 = 0.1721435663121198
# Out:
# (7, 0, 8) 457.3727933686476

# %%
# 使用最优参数组下的 arima 模型
arima_predict, mse, r2 = try_arima(7, 0, 8)
# Out:
# /home/yangxs/.local/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# 绘制 arima 回归线
plt.close()

plt.figure(figsize=(8, 6))
sns.scatterplot(x=time_formal_np.flatten(), y=vol_formal_np.flatten(), label='Actual')
plt.plot(time_formal_np.flatten(), arima_predict, color='red', label='Regression Line (arima, p=7, d=0, q=8)', alpha=0.8)
plt.xlabel('发病到影像检查时间间隔-取对数（h）')
plt.ylabel('水肿总体积（ml）')
plt.xscale('log')
plt.legend()

plt.show()

# %% [markdown]
# ### 机器学习

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #### 支持向量回归

# %% [markdown]
# rbf会过拟合；深度学习方法一律排除
# rbf的R^2会到0.94

# %%
# 随机测试一组参数
svr = SVR(kernel='rbf', C=1e3, gamma=0.1)
svr.fit(time_formal_np, vol_formal_np.ravel())

y_pred = svr.predict(time_formal_np)
r2 = r2_score(vol_formal_np, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: 0.6643573919129002

# %%
# 网格搜索
grid = {'C': [1e2, 1e3, 1e4, 1e5],
              'gamma': [0.01, 0.1, 1, 10,100]}

svr = SVR(kernel='rbf')

grid_search = GridSearchCV(svr, grid, scoring='r2')
grid_search.fit(time_formal_np, vol_formal_np.ravel())

# 输出最佳参数
print("Best Parameters: ", grid_search.best_params_)
print("Best R2 Score: ", grid_search.best_score_)
# Out:
# Best Parameters:  {'C': 100.0, 'gamma': 0.1}
# Best R2 Score:  -0.268136718431557

# %%
# 最优参数过拟合
svr = SVR(kernel='rbf', C=100, gamma=100)
svr.fit(time_formal_np, vol_formal_np.ravel())

y_pred = svr.predict(time_formal_np)
r2 = r2_score(vol_formal_np, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: 0.930583904798836

# %%
svr = SVR(kernel='rbf', C=1e4, gamma=0.1)
svr.fit(time_np, vol_np)

y_pred = svr.predict(time_np)
r2 = r2_score(vol_np, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: 0.6954199731083057

# %%
plt.close()

plt.figure(figsize=(8, 6))
plt.scatter(time_formal_np.flatten(), vol_formal_np.flatten(), color='blue', label='Actual')
# plt.scatter(time, y_pred, color='red', label='Predicted', alpha=0.5)
plt.plot(time_formal_np.flatten(), y_pred, color='red', label='Regression Line (SVM, C=100, gamma=100)', alpha=0.8)
plt.xlabel('发病到影像检查时间间隔-取对数（h）')
plt.ylabel('水肿总体积（ml）')
plt.legend()

plt.show()

# %% [markdown]
# ## 根据论文，假设EED与水肿体积之间的关系

# %%
import math

# %%
# 计算 eed
def get_eed(ed_vol, hm_vol):
    term_1 = ((3 * (ed_vol + hm_vol) / (4 * np.pi)) ** (1/3))
    term_2 = ((3 * (hm_vol) / (4 * np.pi)) ** (1/3))
    return term_1 - term_2

# %%
# 单位为 cm
vol_sorted_eed = get_eed(vol_formal_np.flatten(), hm_formal_np.flatten())

# %%
plt.close()

rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=time_formal_np.flatten(), y=vol_sorted_eed.flatten())

plt.grid(True)
plt.xlabel("发病到影像检查时间间隔-取对数（h）")
plt.ylabel("猜测的水肿EED（cm）")
plt.xscale('log')

plt.show()

# %% [markdown]
# ### 非线性最小二乘

# %%
from scipy.optimize import curve_fit

# %%
# 最小二乘回归

# 定义幂函数模型
def power_func(x, a, b):
    return a * np.power(x, b)

# %%
# 使用最小二乘法进行幂函数回归
params, params_covariance = curve_fit(power_func, time_formal_np.flatten(), vol_sorted_eed)

# 提取回归参数
a = params[0]
b = params[1]

# %%
print("a:", a, "b:", b)
# Out:
# a: 0.18016599172582867 b: 0.23613895684497155

# %%
y_pred = power_func(time_formal_np.flatten(), a, b)

# %%
mse = mean_squared_error(vol_sorted_eed, y_pred)
r2 = r2_score(vol_sorted_eed, y_pred)
print(mse, r2)
# Out:
# 0.13626332656740955 0.23828056919807739

# %%
# mse = mean_squared_error(vol_sorted_eed, y_pred)

# %%
y_pred_vol = (4*np.pi/3) * ((y_pred + (hm_formal_np.flatten() / (4*np.pi/3))**(1/3) )**3) - hm_formal_np.flatten()

# %%
y_pred_vol[:10]
# Out:
# array([ 5.93952945, 11.89279092,  5.53874211,  9.10474416,  4.77857874,
#         9.61720907,  4.89211818,  9.05740692, 10.2196861 , 16.46735297])

# %%
mse = mean_squared_error(vol_formal_np, y_pred_vol)

# %%
r2 = r2_score(vol_formal_np, y_pred_vol)

# %%
r2
# Out:
# 0.0934210351482192

# %%
mse
# Out:
# 500.86529099784224

# %%
plt.close()

rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=time_formal_np.flatten(), y=vol_sorted_eed.flatten())
plt.plot(time_formal_np, y_pred, color='red', label='Regression Line (LS)', alpha=0.8)

plt.grid(True)
plt.xlabel("发病到影像检查时间间隔-取对数（h）")
plt.ylabel("猜测的水肿EED（cm）")
plt.xscale('log')
plt.legend()

plt.show()

# %%
plt.close()

rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=time_formal_np.flatten(), y=vol_formal_np.flatten())
plt.plot(time_formal_np, y_pred_vol, color='red', label='Regression Line (LS)', alpha=0.8)

plt.grid(True)
plt.xlabel("发病到影像检查时间间隔-取对数（h）")
plt.ylabel("水肿体积（ml）")
plt.xscale('log')
plt.legend()

plt.show()

# %% [markdown]
# ### 峰值检测 PEAK（接到后面的分类）
